# %% [markdown]
# # 範例 : (Kaggle)房價預測
# ***
# - 以下用房價預測資料, 觀察去除離群值的影響

# %% [markdown]
# # [教學目標]
# - 以下用房價預測資料, 觀察去除離群值的影響

# %% [markdown]
# # [範例重點]
# - 觀察原始數值的散佈圖, 以及線性迴歸分數 (In[5], Out[5])
# - 觀察將極端值以上下限值取代, 對於分布與迴歸分數的影響 (In[6], Out[6])
# - 觀察將極端值資料直接刪除, 對於分布與迴歸分數的影響 (In[7], Out[7])

# %%
# 做完特徵工程前的所有準備 (與前範例相同)
import pandas as pd
import numpy as np
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

data_path = '../Day_010/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')
pd.set_option('display.float_format',lambda x : '%.3f' % x)
plt.rc('figure', figsize = (10, 6))
# df_train = pd.read_csv(data_path + 'train.zip')

# Train_Y 就是
train_Y = np.log1p(df_train['SalePrice'])
df = df_train.drop(['Id', 'SalePrice'] , axis = 1 )
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL       65.000     8450   Pave   NaN      Reg
# 1          20       RL       80.000     9600   Pave   NaN      Reg
# 2          60       RL       68.000    11250   Pave   NaN      IR1
# 3          70       RL       60.000     9550   Pave   NaN      IR1
# 4          60       RL       84.000    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0       2    2008        WD         Normal
# 1         NaN       0       5    2007        WD         Normal
# 2         NaN       0       9    2008        WD         Normal
# 3         NaN       0       2    2006        WD        Abnorml
# 4         NaN       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
#只取 int64, float64 兩種數值型欄位, 存於 num_features 中
# 將 num_features 建立為 np.array
num_features = np.array([])
# num_features = []

for dtype, feature in tqdm(zip(df.dtypes, df.columns)):
    if dtype == 'float64' or dtype == 'int64':
        num_features = np.append(num_features, feature)
#         num_features.append(feature)
print(f'{len(num_features)} Numeric Features: {num_features}\n')
# Out:
# 79it [00:00, 79232.43it/s]
# 36 Numeric Features: ['MSSubClass' 'LotFrontage' 'LotArea' 'OverallQual' 'OverallCond'
#  'YearBuilt' 'YearRemodAdd' 'MasVnrArea' 'BsmtFinSF1' 'BsmtFinSF2'
#  'BsmtUnfSF' 'TotalBsmtSF' '1stFlrSF' '2ndFlrSF' 'LowQualFinSF'
#  'GrLivArea' 'BsmtFullBath' 'BsmtHalfBath' 'FullBath' 'HalfBath'
#  'BedroomAbvGr' 'KitchenAbvGr' 'TotRmsAbvGrd' 'Fireplaces' 'GarageYrBlt'
#  'GarageCars' 'GarageArea' 'WoodDeckSF' 'OpenPorchSF' 'EnclosedPorch'
#  '3SsnPorch' 'ScreenPorch' 'PoolArea' 'MiscVal' 'MoSold' 'YrSold']

# %%
# 削減文字型欄位, 只剩數值型欄位
df = df[num_features]
# 使用 fillna 方法，將 NA/NAN 值得欄位轉換成其他 value
df = df.fillna(-1, inplace = False)

# 建立傳喚器，預設 feature_range = (0, 1)
MMEncoder = MinMaxScaler()
df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60       65.000     8450            7            5       2003
# 1          20       80.000     9600            6            8       1976
# 2          60       68.000    11250            7            5       2001
# 3          70       60.000     9550            7            5       1915
# 4          60       84.000    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# 0          2003     196.000         706           0  ...         548
# 1          1976       0.000         978           0  ...         460
# 2          2002     162.000         486           0  ...         608
# 3          1970       0.000         216           0  ...         642
# 4          2000     350.000         655           0  ...         836
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0           0           61              0          0            0         0
# 1         298            0              0          0            0         0
# 2           0           42              0          0            0         0
# 3           0           35            272          0            0         0
# 4         192           84              0          0            0         0
#
#    MiscVal  MoSold  YrSold
# 0        0       2    2008
# 1        0       5    2007
# 2        0       9    2008
# 3        0       2    2006
# 4        0      12    2008
#
# [5 rows x 36 columns]

# %%
# 顯示 GrLivArea 地區與目標值(房價)的散佈圖
import seaborn as sns
import matplotlib.pyplot as plt

# x 為 df['GrLivArea']
sns.regplot(x = df['GrLivArea'], y = train_Y)
plt.grid()
plt.show()

# 對 df 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
print(train_X[0])
estimator = LinearRegression()
print(estimator)
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# [0.23529412 0.21019108 0.0334198  0.66666667 0.5        0.94927536
#  0.88333333 0.12304809 0.12508859 0.         0.06421233 0.1400982
#  0.11977972 0.41355932 0.         0.25923135 0.33333333 0.
#  0.66666667 0.5        0.375      0.33333333 0.5        0.
#  0.99651914 0.5        0.3864598  0.         0.11151737 0.
#  0.         0.         0.         0.         0.09090909 0.5       ]
# LinearRegression()
# 0.8466271442393077

# %%
df['GrLivArea'] = df['GrLivArea'].clip(800, 2500)
df['GrLivArea']
# Out:
# 0       1710
# 1       1262
# 2       1786
# 3       1717
# 4       2198
#         ...
# 1455    1647
# 1456    2073
# 1457    2340
# 1458    1078
# 1459    1256
# Name: GrLivArea, Length: 1344, dtype: int64

# %%
# 將 GrLivArea 限制在 800 到 2500 以內, 調整離群值
df['GrLivArea'] = df['GrLivArea'].clip(800, 2500)
sns.regplot(x = df['GrLivArea'], y=train_Y)
plt.grid()
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8765263013479527

# %%
print(len(df['GrLivArea']))

# %%
# 將 GrLivArea 限制在 800 到 2500 以內, 捨棄離群值
keep_indexs = (df['GrLivArea'] > 800) & (df['GrLivArea'] < 2500)
df = df[keep_indexs]
train_Y = train_Y[keep_indexs]
sns.regplot(x = df['GrLivArea'], y = train_Y)
plt.grid()
plt.show()

# 做線性迴歸, 觀察分數
# 規一化: 平等地看待每個權重，而不會因為特徵分布的問題，而造成結果偏向
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8765263013479527

# %% [markdown]
# # 作業1
# * 試著限制 '1樓地板面積(平方英尺)' (1stFlrSF) 欄位的上下限, 看看能否再進一步提高分數?
#
# # 作業2
# * 續前題, 去除離群值有兩類方式 :  捨棄離群值(刪除離群的資料) 以及調整離群值,
# 請試著用同樣的上下限, 改為 '捨棄離群值' 的方法, 看看結果會變好還是變差? 並試著解釋原因。
