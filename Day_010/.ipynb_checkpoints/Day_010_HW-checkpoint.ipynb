# %% [markdown]
# # 作業 : (Kaggle)房價預測

# %% [markdown]
# # [作業目標]
# - 試著模仿範例寫法, 在房價預測中, 觀察去除離群值的影響

# %% [markdown]
# # [作業重點]
# - 觀察將極端值以上下限值取代, 對於分布與迴歸分數的影響 (In[5], Out[5])
# - 觀察將極端值資料直接刪除, 對於分布與迴歸分數的影響 (In[6], Out[6])

# %%
# 做完特徵工程前的所有準備 (與前範例相同)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression


data_path = '../Day_010/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')

train_Y = np.log1p(df_train['SalePrice'])
df = df_train.drop(['Id', 'SalePrice'] , axis=1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# ## 1. EDA(資料探索);視覺化分析

# %%
## 1. 確認Col內的空值
# df_train.isnull()
# df_train[~(df_train.isnull())]
df_RemvNAN = df_train.dropna(axis='columns')
print('The amount of columns remain: ', len(df_RemvNAN.columns))
print('The amount of columns remain: ', len(df_train.columns))
# Out:
# The amount of columns remain:  62
# The amount of columns remain:  81

# %%
# df_train['SalePrice']的各種資訊
df_saleprice = df_train['SalePrice']
df_saleprice.describe().loc['std']
# Out:
# 79442.50288288663

# %%
# idnetify outlier 
cut_off = df_saleprice.describe().loc['std'] * 3
print(cut_off)
mean = df_saleprice.describe().loc['mean']
print(mean)
lower, upper = float(mean - cut_off), float(mean + cut_off) 
print(lower, upper)

boxplot_df = df_train[(df_train['SalePrice'] > lower) & (df_train['SalePrice'] < upper)].reset_index()
boxplot_df.boxplot(column = 'SalePrice')
# Out:
# 238327.50864865992
# 180921.19589041095
# -57406.31275824897 419248.70453907084
# <AxesSubplot:>

# %%
# 查看在df_train內的['SalePrice']的數值分布狀況
df_train.boxplot(column = ['SalePrice'])
# Out:
# <AxesSubplot:>

# %%
# 找取再 3個 std 內的資料
boxplot_df = df_train.loc[df_train['SalePrice'] < df_train['SalePrice'].quantile(0.99)].reset_index()

# 找取再 3個 std 內的資料
boxplot_df = df_train['SalePrice'].clip(lower, upper).reset_index()
boxplot_df.boxplot(column = ['SalePrice'])
# Out:
# <AxesSubplot:>

# %%
# 找出outliers，並確認是在index多少跟多少
outlier_df = df_train.loc[(df_train['SalePrice'] > df_train['SalePrice'].quantile(0.99)) | (df_train['SalePrice'] < df_train['SalePrice'].quantile(0.01))]
print(outlier_df['SalePrice'].reset_index())
# outlier_df.boxplot(column = 'SalePrice')
# Out:
#     index  SalePrice
# 0      30      40000
# 1     178     501837
# 2     185     475000
# 3     375      61000
# 4     410      60000
# 5     440     555000
# 6     495      34900
# 7     527     446261
# 8     533      39300
# 9     591     451950
# 10    636      60000
# 11    691     755000
# 12    705      55000
# 13    710      52000
# 14    769     538000
# 15    798     485000
# 16    803     582933
# 17    812      55993
# 18    898     611657
# 19    916      35311
# 20    968      37900
# 21   1046     556581
# 22   1100      60000
# 23   1169     625000
# 24   1182     745000
# 25   1243     465000
# 26   1325      55000
# 27   1337      52500
# 28   1373     466500
# 29   1380      58500

# %% [markdown]
# # 開始找數值型資料

# %%
# 做完特徵工程前的所有準備 (與前範例相同)
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

data_path = '../Day_010/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')
pd.set_option('display.float_format',lambda x : '%.3f' % x)
plt.rc('figure', figsize = (10, 6))

train_Y = np.log1p(df_train['SalePrice'])
df = df_train.drop(['Id', 'SalePrice'] , axis=1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL       65.000     8450   Pave   NaN      Reg
# 1          20       RL       80.000     9600   Pave   NaN      Reg
# 2          60       RL       68.000    11250   Pave   NaN      IR1
# 3          70       RL       60.000     9550   Pave   NaN      IR1
# 4          60       RL       84.000    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# 只取 int64, float64 兩種數執行欄位， 存於 num_features 中
num_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'float64' or dtype == 'int64':
        num_features.append(feature)
print(f'{len(num_features)} Numeric Featrues : {num_features}\n')
# Out:
# 36 Numeric Featrues : ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
df = df[num_feature]
df = df.fillna(-1)
MMncoder = MinMaxScaler()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-963d1e20a54f> in <module>
# ----> 1 df = df[num_feature]
#       2 df = df.fillna(-1)
#       3 MMncoder = MinMaxScaler()
#
# NameError: name 'num_feature' is not defined

# %%
# 削減文字型欄位, 只剩數值型欄位
df = df[num_features]
# 將欄位內空值轉換成 -1
df = df.fillna(-1, inplace = False)
# 
MMEncoder = MinMaxScaler()
train_num = train_Y.shape[0]
# df.head()
df[df.isnull() != True]
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60       65.000     8450            7            5       2003
# 1             20       80.000     9600            6            8       1976
# 2             60       68.000    11250            7            5       2001
# 3             70       60.000     9550            7            5       1915
# 4             60       84.000    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60       62.000     7917            6            5       1999
# 1456          20       85.000    13175            6            6       1978
# 1457          70       66.000     9042            7            9       1941
# 1458          20       68.000     9717            5            6       1950
# 1459          20       75.000     9937            5            6       1965
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 作業2(捨棄離群值)
# * 續前題, 去除離群值有兩類方式 :  捨棄離群值(刪除離群的資料) 以及調整離群值,
# 請試著用同樣的上下限, 改為 '捨棄離群值' 的方法, 看看結果會變好還是變差? 並試著解釋原因。

# %%
# 做完特徵工程前的所有準備 (與前範例相同)
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

data_path = '../Day_010/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')
pd.set_option('display.float_format',lambda x : '%.3f' % x)
plt.rc('figure', figsize = (10, 6))

train_Y = np.log1p(df_train['SalePrice'])
df = df_train.drop(['Id', 'SalePrice'] , axis=1)
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL       65.000     8450   Pave   NaN      Reg
# 1          20       RL       80.000     9600   Pave   NaN      Reg
# 2          60       RL       68.000    11250   Pave   NaN      IR1
# 3          70       RL       60.000     9550   Pave   NaN      IR1
# 4          60       RL       84.000    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 1         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 3         Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 4         Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# 只取 int64, float64 兩種數執行欄位， 存於 num_features 中
num_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'float64' or dtype == 'int64':
        num_features.append(feature)
print(f'{len(num_features)} Numeric Featrues : {num_features}\n')
# Out:
# 36 Numeric Featrues : ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
# 削減文字型欄位, 只剩數值型欄位
df = df[num_features]
# 將欄位內空值轉換成 -1
df = df.fillna(-1)

# 利用 MinMaxScaler 找尋最好的參數
MMEncoder = MinMaxScaler()
train_num = train_Y.shape[0]
df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60       65.000     8450            7            5       2003
# 1          20       80.000     9600            6            8       1976
# 2          60       68.000    11250            7            5       2001
# 3          70       60.000     9550            7            5       1915
# 4          60       84.000    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# 0          2003     196.000         706           0  ...         548
# 1          1976       0.000         978           0  ...         460
# 2          2002     162.000         486           0  ...         608
# 3          1970       0.000         216           0  ...         642
# 4          2000     350.000         655           0  ...         836
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
# 顯示 1stFlrSF 與目標值的散佈圖
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x = df['1stFlrSF'][:train_num], y=train_Y)
plt.grid()
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8466271442393077

# %%
# 這邊是刪除 df['1stFlrSF'] 的值是在範圍 90% ~ 10% 之間的 index
# df['1stFlrSF'] = df['1stFlrSF'][(df['1stFlrSF'] < df['1stFlrSF'].quantile(0.90)) & (df['1stFlrSF'] > df['1stFlrSF'].quantile(0.10))]

# 紀錄 df['1stFlrSF'] 的值是在範圍 90% ~ 10% 之間的 index
keep_indexs = (df['1stFlrSF'] < df['1stFlrSF'].quantile(0.90)) & (df['1stFlrSF'] > df['1stFlrSF'].quantile(0.10))
print(keep_indexs.head(10))
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 23     True
# 24     True
# 25    False
# 26     True
# 28    False
# 31     True
# 32     True
# 34    False
# 35     True
# Name: 1stFlrSF, dtype: bool

# %%
# 將第一層樓再 90% & 10% 以外的值都 "刪除" 
df = df[keep_indexs]
train_Y = train_Y[keep_indexs]

df['1stFlrSF'].isnull().sum()
# Out:
# 0

# %%
# 將遺失值視覺化
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr() # 產生相關係數矩陣
# 改變矩陣
plt.figure(figsize = (10, 8)) 
sns.heatmap(corr, cmap = 'PuOr')
# Out:
# <AxesSubplot:>

# %%
# 將 1stFlrSF 限制在你覺得適合的範圍內, 調整離群值
# df_train['1stFlrSF'] = df_train['1stFlrSF'][(df_train['1stFlrSF'] < df_train['1stFlrSF'].quantile(0.90)) | (df_train['1stFlrSF'] > df_train['1stFlrSF'].quantile(0.01))]
# df['1stFlrSF'] = df['1stFlrSF'][(df['1stFlrSF'] < df['1stFlrSF'].quantile(0.90)) & (df['1stFlrSF'] > df['1stFlrSF'].quantile(0.10))]
sns.regplot(x = df['1stFlrSF'], y=train_Y)
# print(df['1stFlrSF'].isnull().sum(), train_Y.isnull().sum())
plt.grid()
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0 0
# 0.875025522385876

# %% [markdown]
# ---
# # 作業1 (調整離群值)
# * 試著限制 '1樓地板面積(平方英尺)' (1stFlrSF) 欄位的上下限, 看看能否再進一步提高分數?

# %%
# 做完特徵工程前的所有準備 (與前範例相同)
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

data_path = '../Day_010/'
df_train = pd.read_csv(data_path + 'house_train.csv.gz')
pd.set_option('display.float_format',lambda x : '%.3f' % x)
plt.rc('figure', figsize = (10, 6))

# 將 DataFrame 內的 SalePrice 取 log 值
train_Y = np.log1p(df_train['SalePrice'])
# 把 DataFrame 的 Id & SalePrice 欄位去除，並重新定義一個 df
df = df_train.drop(['Id', 'SalePrice'] , axis=1)

# 只取 int64, float64 兩種數執行欄位， 存於 num_features 中
num_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'float64' or dtype == 'int64':
        num_features.append(feature)
print(f'{len(num_features)} Numeric Featrues : {num_features}\n')

df = df[num_features]
df = df.fillna(-1)
# 數值正規化
MinMaxBox = MinMaxScaler()
# Out:
# 36 Numeric Featrues : ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
# 這邊利用常態分布的想法來做，取 +-1 個標準差的範圍
mean_val = df['1stFlrSF'].describe()['mean'] 
std_val = df['1stFlrSF'].describe()['std'] * 1

min_val = mean_val + std_val
max_val = mean_val - std_val

# %%
# 將 1stFlrSF 限制在你覺得適合的範圍內, 捨棄離群值
df['1stFlrSF'] = df['1stFlrSF'].clip(min_val, max_val)
sns.regplot(x = df['1stFlrSF'], y=train_Y)
plt.grid()
plt.show()

# 做線性迴歸, 觀察分數
train_X = MMEncoder.fit_transform(df)
estimator = LinearRegression()
cross_val_score(estimator, train_X, train_Y, cv=5).mean()
# Out:
# 0.8510035081361303
