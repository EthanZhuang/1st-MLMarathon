# %% [markdown]
# 請至以下機器學習巨頭的 blog 參觀，試著閱讀一篇文章並分析其
#
# 作業 1：目標
#
# 作業 2：方法
#
# 作業 3：資料來源
#
# * [Google Ai Blog](https://ai.googleblog.com/)
# * [Facebook Research blog](https://research.fb.com/blog/)
# * [Apple Machine Journal](https://machinelearning.apple.com/)
# * [機械之心](https://www.jiqizhixin.com/)
# * [雷鋒網](https://www.leiphone.com/category/ai)

# %% [markdown]
# * The goal:
#     Keeping the quality of speech recognition high for speakers
# * Motivation:
#     [How Ai can imporove products for people with impaired speech](https://www.blog.google/outreach-initiatives/accessibility/impaired-speech-recognition/)
# * The method:
#     many layers is necessary(e.g. preprocessing, feature extraction, optimization, prediction, decision making)
#     - There is a dataset for nine primary Indian languages.
#     - They used a Recurrent Neural Network Transducer(RNN-T) model to achieve streaming E2E ASR.
#     - It's only need sole language from the audio training data.
# Tradition ASR systems contain separate components for acoustic, pronunciation, and language models.
# ![image.png](attachment:image.png)
#
#
# 3. Reference: Google AI Blog
#
# [Large-Scale Multilingual Speech Recognition with a Straeaming End-to-End Model](https://ai.googleblog.com/2019/09/large-scale-multilingual-speech.html)
# Researchers: Tara N. Sainath, Eugene Weinstein, Bo Li, Shubham Toshniwal, Ron Weiss, Bhuvana Ramabhadran, Yonghui Wu, Ankur Bapna, Zhifeng Chen, Seungji Lee, Meysam Bastani, Mikaela Grace, Pedro Moreno, Yanzhang (Ryan) He, Khe Chai Sim.
